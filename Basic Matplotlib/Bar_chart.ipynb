# %% [markdown]
# # Bar Chart

# %% [markdown]
# <img src="barchart.jpg" alt = "Bar chart" width = "550">

# %% [markdown]
# When we use 2D plot?
#
# <ul>
#     <li>Bivariate Analysis</li>
#     <li>Numerical Vs Categorical</li>
#     <li>Use case --> Aggregate analysis of groups</li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# simple bar chart
children = [10, 15, 12, 23, 18, 9, 20]
colors = ['red', 'blue', 'green', 'black', 'yellow', 'orange', 'purple']

plt.bar(colors, children, color = 'purple')
# Out:
# <BarContainer object of 7 artists>

# %%
# bar chart using data

# %%
# horizontal bar chart
plt.barh(colors, children, color = 'green')
# Out:
# <BarContainer object of 7 artists>

# %%
# color and label

# %%
# Multiple bar chart
